# 2024-01-23 10:45:00+05:30  1442.400024  1446.650024  1440.349976  1443.500000
#
#                            Volume  Dividends  Stock Splits         VWAP
# Datetime
# 2023-10-27 09:15:00+05:30   49188        0.0           0.0  1467.500000
# 2023-10-27 09:30:00+05:30   27036        0.0           0.0  1469.291209
# 2023-10-27 09:45:00+05:30   18952        0.0           0.0  1470.577321
# 2023-10-27 10:00:00+05:30   34296        0.0           0.0  1471.166102
# 2023-10-27 10:15:00+05:30   17810        0.0           0.0  1471.285083
# ...                           ...        ...           ...          ...
# 2024-01-23 09:45:00+05:30   87910        0.0           0.0  1578.111566
# 2024-01-23 10:00:00+05:30   39614        0.0           0.0  1577.986631
# 2024-01-23 10:15:00+05:30   35549        0.0           0.0  1577.869248
# 2024-01-23 10:30:00+05:30   29726        0.0           0.0  1577.772782
# 2024-01-23 10:45:00+05:30   21669        0.0           0.0  1577.702887
#
# [1457 rows x 8 columns]

# %%
last_row = data1.iloc[-1]
secound_last_row = data1.iloc[-2]

print(f"last_row['Close'] : {last_row['Close']}")
print(f"last_row['VWAP'] : {last_row['VWAP']}")
print(f"secound_last_row['Close'] : {secound_last_row['Close']}")
print(f"secound_last_row['VWAP'] : {secound_last_row['VWAP']}")
# Out:
# last_row['Close'] : 1443.5
# last_row['VWAP'] : 1577.702887252939
# secound_last_row['Close'] : 1442.8499755859375
# secound_last_row['VWAP'] : 1577.7727816836955

# %%
if secound_last_row['Close'] > secound_last_row['VWAP'] and last_row['Close'] < last_row['VWAP']:
  print("Cross Under")
if secound_last_row['Close'] < secound_last_row['VWAP'] and last_row['Close'] > last_row['VWAP']:
  print("Cross Over")
else:
  print('No Cross')
# Out:
# No Cross

# %%
angelOne = yf.Ticker("ANGELONE.BO")

# %%
angel_data = angelOne.history(interval = '1d', period = '360d')

# %%
angel_data.tail()
# Out:
#                                   Open         High     Low        Close  \
# Date
# 2024-01-15 00:00:00+05:30  3800.000000  3893.449951  3729.0  3874.699951
# 2024-01-16 00:00:00+05:30  3500.000000  3607.850098  3280.0  3328.300049
# 2024-01-17 00:00:00+05:30  3375.050049  3496.199951  3241.0  3336.649902
# 2024-01-19 00:00:00+05:30  3350.000000  3375.000000  3299.0  3336.800049
# 2024-01-23 00:00:00+05:30  3251.449951  3297.500000  3095.0  3121.149902
#
#                            Volume  Dividends  Stock Splits
# Date
# 2024-01-15 00:00:00+05:30   34658        0.0           0.0
# 2024-01-16 00:00:00+05:30  126670        0.0           0.0
# 2024-01-17 00:00:00+05:30   48971        0.0           0.0
# 2024-01-19 00:00:00+05:30   26650        0.0           0.0
# 2024-01-23 00:00:00+05:30   35664       12.7           0.0

# %%
angel_data.reset_index(inplace = True)

# %%
angel_data

# %%
angel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          343 non-null    datetime64[ns, Asia/Kolkata]
#  1   Open          343 non-null    float64
#  2   High          343 non-null    float64
#  3   Low           343 non-null    float64
#  4   Close         343 non-null    float64
#  5   Volume        343 non-null    int64
#  6   Dividends     343 non-null    float64
#  7   Stock Splits  343 non-null    float64
# dtypes: datetime64[ns, Asia/Kolkata](1), float64(6), int64(1)
# memory usage: 21.6 KB

# %%
angel_data['Date'].dt.date
# Out:
# 0      2022-08-10
# 1      2022-08-11
# 2      2022-08-12
# 3      2022-08-16
# 4      2022-08-17
#           ...
# 338    2024-01-15
# 339    2024-01-16
# 340    2024-01-17
# 341    2024-01-19
# 342    2024-01-23
# Name: Date, Length: 343, dtype: object

# %%
angel_data['Date'] = angel_data['Date'].dt.date

# %%
# angel_data.drop('Date_1', axis = 1, inplace = True)

# %%
# current_date = angel_data.Date.max(2) + timedelta(days = 1)
current_date = angel_data['Date'].nlargest(2).iloc[-1]
current_date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-4360426b6a72> in <cell line: 2>()
#       1 # current_date = angel_data.Date.max(2) + timedelta(days = 1)
# ----> 2 current_date = angel_data['Date'].nlargest(2).iloc[-1]
#       3 current_date
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in nlargest(self, n, keep)
#    4132         dtype: int64
#    4133         """
# -> 4134         return algorithms.SelectNSeries(self, n=n, keep=keep).nlargest()
#    4135
#    4136     def nsmallest(self, n: int = 5, keep: str = "first") -> Series:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in nlargest(self)
#    1275     @final
#    1276     def nlargest(self):
# -> 1277         return self.compute("nlargest")
#    1278
#    1279     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in compute(self, method)
#    1315         dtype = self.obj.dtype
#    1316         if not self.is_valid_dtype_n_method(dtype):
# -> 1317             raise TypeError(f"Cannot use method '{method}' with dtype {dtype}")
#    1318
#    1319         if n <= 0:
#
# TypeError: Cannot use method 'nlargest' with dtype object

# %%
from dateutil.relativedelta import relativedelta

# %%
One_month_ago =  current_date - relativedelta(months=1)
Three_month_ago = current_date - relativedelta(months=3)
Six_month_ago = current_date - relativedelta(months=6)
print(current_date)
print(One_month_ago)
print(Three_month_ago)
print(Six_month_ago)
# Out:
# 2024-01-19 00:00:00+05:30
# 2023-12-19 00:00:00+05:30
# 2023-10-19 00:00:00+05:30
# 2023-07-19 00:00:00+05:30

# %%
date_list = [current_date, One_month_ago, Three_month_ago, Six_month_ago]
date_list
# Out:
# [datetime.date(2024, 1, 24),
#  datetime.date(2023, 12, 24),
#  datetime.date(2023, 10, 24),
#  datetime.date(2023, 7, 24)]

# %%
ava_data = []
# prev_date = [-1,-2,-3,-4,-5,-6,-7,-8]
for elm in date_list:
  i = -1
  if elm in (angel_data['Date'].values):
    ava_data.append(elm)
  else:
    while True:
      offset_date = elm + timedelta(days = i)
      if offset_date in (angel_data['Date'].values):
        ava_data.append(offset_date)
        break
      i -= 1

# %%
ava_data
# Out:
# [datetime.date(2024, 1, 23),
#  datetime.date(2023, 12, 22),
#  datetime.date(2023, 10, 23),
#  datetime.date(2023, 7, 24)]

# %%
# current_date + timedelta(days =1)

# %%
current_date_1   =  pd.Timestamp('2023-07-18')

# %%
# def date_check(df):
#   # date = current_date - relativedelta(months=1)
#   date = current_date_1
#   if date in (angel_data['Date'].values):
#     return True
#   else:
#     return False

# %%
len(ava_data)
# Out:
# 4

# %%
ava_data[1]
# Out:
# datetime.date(2023, 12, 22)

# %%
# def average_price(df, ava_data):
#   for elm in ava_data:
#     i = 0
#     ava_data = sorted(ava_data)
#     month_1 = df[(df['Date'] <= ava_data[i]) & (df['Date'] >= ava_data[i+1])]
#     # month_1_avg = month_1.Close.mean()
#     # month_3 = df[(df['Date'] <=ava_data[i]) & (df['Date'] >= ava_data[i+2])]
#     # month_3_avg = month_3.Close.mean()
#     # month_6 = df[(df['Date'] <=ava_data[i]) & (df['Date'] >= ava_data[i+3])]
#     # month_6_avg = month_6.Close.mean()

#     # average_price = pd.merge(month_1_avg,month_3_avg,month_6_avg)

#     return month_1

# %%
def average_price(df, ava_data):
    ava_data = sorted(ava_data, reverse = True)
    result_data = []
    start_date = ava_data[0]
    for i in range(len(ava_data)-1):  # Loop over the date ranges
        # start_date = ava_data[i]
        end_date = ava_data[i + 1]

        # Filter the DataFrame based on the date range
        month_data = df[(df['Date'] <= start_date) & (df['Date'] >= end_date)]

        # Calculate and store the average price for the month
        if not month_data.empty:
            average_price = round(month_data['Close'].mean(),2)
            result_data.append({'Start Date': start_date, 'End Date': end_date, 'Average Price': average_price})

    return result_data

# Example usage:
result = average_price(angel_data, ava_data)
# print(result)
result
# Out:
# [{'Start Date': datetime.date(2024, 1, 23),
#   'End Date': datetime.date(2023, 12, 22),
#   'Average Price': 3532.18},
#  {'Start Date': datetime.date(2024, 1, 23),
#   'End Date': datetime.date(2023, 10, 23),
#   'Average Price': 3101.86},
#  {'Start Date': datetime.date(2024, 1, 23),
#   'End Date': datetime.date(2023, 7, 24),
#   'Average Price': 2490.24}]

# %%
data2 = pd.DataFrame(result)
data2
# Out:
#    Start Date    End Date  Average Price
# 0  2024-01-23  2023-12-22        3532.18
# 1  2024-01-23  2023-10-23        3101.86
# 2  2024-01-23  2023-07-24        2490.24

# %%
mean_price = [result[0]['Average Price'],result[1]['Average Price'],result[2]['Average Price']]
mean_price
# Out:
# [3532.18, 3101.86, 2490.24]

# %%
mean_price = [result[0]['Average Price'],result[1]['Average Price'],result[2]['Average Price']]

ange_one_avg_price = pd.DataFrame(mean_price, columns = ["Avg_price"], index = ["1M", "3M", "6M"])
ange_one_avg_price
# Out:
#     Avg_price
# 1M    3532.18
# 3M    3101.86
# 6M    2490.24
